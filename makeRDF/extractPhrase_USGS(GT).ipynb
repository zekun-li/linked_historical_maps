# %%
"""
# extract phrase from ground truth
# USGS-15-CA-hesperia-e1902-s1898-rp1912: empty data, so not used

input: USGS annotation csv files (ground truth) in "input_usgs" folder
output: map_phrase_USGS(GT).json {map: [phrases]}
"""

import glob
import pandas as pd

# read all input files and check column names
for filename in glob.glob("input_usgs/*.csv"):
    print(filename)
    print(pd.read_csv(filename).columns)
    print("========")
# Out:
# input_usgs\USGS-15-CA-brawley-e1957-s1957-p1961.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-15-CA-capesanmartin-e1921-s1917.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-15-CA-paloalto-e1899-s1895-rp1911.csv
# Index(['id', 'text', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-15-CA-sanfrancisco-e1899-s1892-rp1911.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-30-CA-dardanelles-e1898-s1891-rp1912.csv
# Index(['TXT', 'Phrase', 'TXT_LOC', 'ID'], dtype='object')
# ========
# input_usgs\USGS-30-CA-holtville-e1907-s1905-rp1946.csv
# Index(['id', 'TXT', 'PHRASE', 'TXT_LOC'], dtype='object')
# ========
# input_usgs\USGS-30-CA-indiospecial-e1904-s1901-rp1910.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-30-CA-lompoc-e1943-s1903-ap1941-rv1941.csv
# Index(['ID', 'TXT', 'PHRASE', 'TXT_LOC'], dtype='object')
# ========
# input_usgs\USGS-30-CA-sanpedro-e1943-rv1944.csv
# Index(['id', 'TXT', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-60-CA-alturas-e1892-rp1904.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-60-CA-amboy-e1942.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-60-CA-amboy-e1943-rv1943.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-60-CA-modoclavabed-e1886-s1884.csv
# Index(['id', 'txt', 'phrase', 'txt_loc'], dtype='object')
# ========
# input_usgs\USGS-60-CA-saltonsea-e1943-ap1940-rv1942.csv
# Index(['id', 'Name', 'Text', 'Position'], dtype='object')
# ========

# %%
# make phrase set per each map jpg file
# remove nan, lowercase
phrase_dic = dict()

for filename in glob.glob("input/*.csv"):
    key = filename[6:-3] +'jpg'
    try:
        try:
            phrase_dic[key] = list(set([ele.lower() for ele in set(pd.read_csv(filename).phrase) if str(ele) != 'nan']))
        except:
            phrase_dic[key] = list(set([ele.lower() for ele in set(pd.read_csv(filename).PHRASE) if str(ele) != 'nan']))
    except:
        try:
            phrase_dic[key] = list(set([ele.lower() for ele in set(pd.read_csv(filename).Phrase) if str(ele) != 'nan']))
        except:
            phrase_dic[key] = list(set([ele.lower() for ele in set(pd.read_csv(filename).Text) if str(ele) != 'nan']))

# %%
phrase_dic
# Out:
# {'101201496.jpg': ['b.o.',
#   'euston road',
#   "king's cross works",
#   'travelling circle',
#   'providence row',
#   'metropolitan railway',
#   'coal shoot',
#   'argyle place',
#   'p.o.',
#   'manchester street',
#   'albion yard',
#   'f.a',
#   'boys',
#   'f.h.',
#   '55•4',
#   'liverpool street',
#   'platform no. 2',
#   'middlesex street',
#   'hampden house',
#   'wilsted cottages',
#   'platform no. 7',
#   'belgrave street',
#   'church way',
#   "king's cross",
#   'air shaft',
#   'theatre',
#   'clarendon square',
#   '58•5',
#   'b.m. 54•87',
#   'union & parly. boro. bdy.',
#   'equity buildings',
#   '60•3',
#   'travelling crane',
#   'coal shoots',
#   'lavina grove',
#   'caledonian road',
#   'girls & infants',
#   'b.m. 70•16',
#   'cheney street',
#   '68•0',
#   '56•9',
#   'presby. chapel',
#   'f.w',
#   "king's cross station (metropolitan)",
#   'tonbridge street',
#   'b.m. 57•90',
#   '61•0',
#   's.b',
#   'black lead & blue works',
#   'platform no. 4',
#   'field',
#   'b.p',
#   'brill street',
#   '63•3',
#   "king's cross station (suburban)",
#   '74•2',
#   'chapel mews',
#   'refreshment room',
#   'offices',
#   'platform no. 1',
#   'b.m. 72•24',
#   'b.m. 63•41',
#   'somers town',
#   'drummond crescent',
#   'convent',
#   'b.m. 85•73',
#   'tanks',
#   'b.m. 70•04',
#   '65•9',
#   'netherland place',
#   'b.m. 69•81',
#   '70•4',
#   'red lion passage',
#   'clarence passage',
#   '65•2',
#   '52•9',
#   '73•3',
#   'providence road',
#   'b.m. 66•92',
#   'wicklow street',
#   'und.',
#   'chapel grove',
#   'wharf road',
#   'caledonian crescent',
#   'phoenix street',
#   'booking hall',
#   "home & colonial society's training college & schools",
#   'p.l.b',
#   'urinal',
#   'seats for 1200',
#   'p.h.',
#   'c.r.',
#   'cab stand',
#   'wharfdale road',
#   'eastnor place',
#   '52•5',
#   'north street',
#   'police station (y. division)',
#   'platform no. 6',
#   'chapel street',
#   '54•9',
#   'square',
#   'albion street',
#   'seymour court',
#   '61•5',
#   'midland railway',
#   'railway street',
#   'bidborough street',
#   'ossulston place',
#   '62•2',
#   'leather works',
#   'b.m. 68•28',
#   'r.c. chapel',
#   'f.p',
#   'roberts yard',
#   'b.m. 51•39',
#   'infants',
#   '64•1',
#   'b.m. 58•98',
#   "st. chad's place",
#   'weirs passage',
#   'hotel curve',
#   'platt street',
#   'chalton street',
#   'pancras road',
#   'boston yard',
#   'school',
#   'culross building',
#   'alpha place',
#   '70•8',
#   '70•5',
#   'b.s',
#   'gymnasium',
#   '58•0',
#   'b.m. 71•40',
#   'stanmore street',
#   'phenoix street',
#   'caledonia street',
#   '54•6',
#   'midland road',
#   'battle bridge (site of)',
#   'gas works',
#   '55•3',
#   'york buildings',
#   '56•4',
#   'cartridge case',
#   '54•1',
#   'christ church',
#   'school girls',
#   'coal depot',
#   'g.n.r.',
#   'argyle square',
#   'drummond street',
#   'b.m. 55•62',
#   'b.m. 71•29',
#   'swedenborgian chapel',
#   '54•5',
#   'l.b',
#   'throat & ear hospital',
#   'christopher place',
#   'b.m. 67•85',
#   'goods shed',
#   'b.m. 67•16',
#   "st. jude's church",
#   'battle bridge road',
#   'chapel place',
#   "king's cross station",
#   'buckingham mews',
#   'div. of parly. boro. bdy.',
#   'argyle street',
#   'smithy',
#   'little drummond street',
#   'hampden street',
#   'street',
#   "home and colonial society's training college & schools",
#   'great northern hotel',
#   'platform no. 3',
#   "gravy's inn road",
#   'derby mews',
#   'wellesley street',
#   'charrinton street',
#   'st. pancras station',
#   'crescent avenue',
#   "weller's court",
#   'aldenham street',
#   'albion tin works',
#   'crescent place',
#   'b.m. 58•67',
#   '57•4',
#   'lift',
#   's.p',
#   'chesterfield street',
#   'w.m',
#   '62•1',
#   'clarendon grove',
#   'subway',
#   'milland grand hotel',
#   'mission hall',
#   'b.m. 65•73',
#   'dining room',
#   'foundry (iron)',
#   'office',
#   '70•9',
#   'lancing street',
#   'ossulton street',
#   'derby street',
#   'milk shed',
#   'b.m. 68•88',
#   '54•91',
#   'parly. co. div., union & parly. boro. bdy',
#   'd.f',
#   'b.m. 59•11',
#   '66•3',
#   'bottle works',
#   '65•1',
#   'bottled beer stores',
#   'b.m. 56•91',
#   'vicarage',
#   '68•4',
#   'b.m. 74•22',
#   'trough d.f urinal',
#   'chapel',
#   'york road',
#   'pentonville road',
#   'platform no. 5',
#   'st. pancras emery & black lead works',
#   'platform',
#   'vent',
#   'meth. chap. (welsleyan)',
#   'girls',
#   'seats for 800',
#   '55•2',
#   'f.h',
#   'stanley buildings',
#   '59•7',
#   'p.lb',
#   'b.m. 67•45',
#   'b.m. 66•10',
#   'tramway',
#   'osulton street',
#   'boys & girls',
#   'bank'],
#  '102903919.jpg': ['euston road',
#   'hollisfield',
#   'sandwich street',
#   'lucas house',
#   'regent square',
#   'travistock place',
#   'belgrove street',
#   'bedefield',
#   "king's cross bridge",
#   'station',
#   'sandfield',
#   'thanet street',
#   "king's cross",
#   'statue',
#   'midhope street',
#   'riverside',
#   'canterbury hall (university of londong)',
#   'tagesden',
#   'northumberland hotel',
#   'tonbridge street',
#   "gray's inn road",
#   'bottling stores',
#   'gaumont theater',
#   'methodist church',
#   'seafood street',
#   'hastings houses',
#   'confectionery works',
#   'clifton house',
#   'cromer house',
#   'crestfield street',
#   'tonbridge houses',
#   'holy cross church',
#   'argyle walk',
#   'whidborne street',
#   'wakefield street',
#   'queen alexandra mansions',
#   'ferris house',
#   'medthodist church',
#   'regent theatre',
#   'cartwright gardens',
#   'bidborough street',
#   'tonbridge club',
#   'fleetfield',
#   'jessel house',
#   'rashleigh house',
#   'el sub sta',
#   'charlwood houses',
#   'pancras road',
#   'chadswell',
#   'school',
#   'sandwich house',
#   'wakefield mews',
#   'mabledon place',
#   'kings cross and st pancras station',
#   'engineering works',
#   'whidborne buildings',
#   'seafood works',
#   'hastings street',
#   "st chad's street",
#   'town hall',
#   'unionist club',
#   'ruins',
#   'midland road',
#   'midhope buildings',
#   'argyle square',
#   'great croft',
#   'clare court',
#   'ward bdy',
#   'tankerton street',
#   'goods shed',
#   "king's cross station",
#   'queen alexandra masions',
#   'harrison street',
#   'argyle street',
#   'belgrove house',
#   'tankerton houses',
#   'great northern hotel',
#   'thanet street hall',
#   'st pancras station',
#   'sinclair house',
#   'kellet houses',
#   'st pancras chambers',
#   'loxham st',
#   'leigh street',
#   'riverfleet',
#   'judd street',
#   'cromer street',
#   'subway',
#   'mission hall',
#   'telephone exchange',
#   "st peter's church",
#   'birkenhead street',
#   'met b & boro const bdy',
#   "king's cross and st pancras station",
#   'pentonville road',
#   'hamilton house',
#   'platform',
#   'willing house',
#   'thanet house',
#   'fleetway',
#   'sidmouth street',
#   'speedy place',
#   "st chad's place",
#   'bank',
#   'mulletsfield'],
#  '102903922.jpg': ['vernon rise',
#   "king's cross road",
#   'prospect terrace',
#   'clothing factory',
#   'percy circus',
#   'prideaux house',
#   'ampton place',
#   'ampton street',
#   'air shaft',
#   'britannia street',
#   'model buildings',
#   'baptist church',
#   'vernon square',
#   'hostel',
#   'h ramp',
#   "gray's inn road",
#   'iron works',
#   'pakenham street',
#   'police station',
#   'frederick street',
#   'the royal national throat nose and ear hospital',
#   'bottling depot',
#   'the bell',
#   'cubitt street',
#   'printing works',
#   'vernon baptist church',
#   "king's cross street",
#   'iron foundry',
#   'wicklow street',
#   'stanley house',
#   'prideaux place',
#   'vernon hall',
#   'nurses home',
#   'granville',
#   'rowton house',
#   'granville street',
#   'ph',
#   'magistrates court',
#   'granville square',
#   'el sub sta',
#   'holford place',
#   'the pinder of wakefield',
#   'swinton place',
#   'heathcote street',
#   'playground',
#   'garage',
#   'school',
#   'weston rise',
#   'royal free hospital',
#   'engineering works',
#   'institute',
#   'ruins',
#   'sidmouth mews',
#   'peperfield',
#   'field street',
#   'trough',
#   'holford plae',
#   'swinton street',
#   'chy',
#   'lloyd baker street',
#   'ruin',
#   'harrison street',
#   'argyle street',
#   'ramp',
#   'school house',
#   'platforms',
#   'cromer street',
#   'telephone exchange',
#   'gwynne place',
#   'boot factory',
#   'acton street',
#   'met b & boro const bdy',
#   'argle street',
#   'swinton house bank',
#   'wharton street',
#   'fiona house',
#   'lorenzo street',
#   'platform',
#   'thei pinder of wakefield',
#   'great percy street',
#   'leeke street',
#   'penton rise',
#   'sidmouth street',
#   'clinic',
#   "st chad's place",
#   'bank',
#   'derby buildings',
#   'pioneer house'],
#  '102903925.jpg': ['cemetery (disused)',
#   'colonnade',
#   '(london transport)',
#   'travistock place',
#   'henrietta mews',
#   'institute of opthamology',
#   'presbyterian church',
#   'herbrand street',
#   'woburn mews',
#   'peabody buildings',
#   'school of medicine (royal free hosply)',
#   'hotel russell',
#   'handel street',
#   'bernard mansions',
#   'downing court',
#   'statue',
#   'queen square place',
#   'thackeray buildings',
#   'waverley mansions',
#   'warhouse',
#   'dickens buildings',
#   'compton place',
#   'brunswick mansions',
#   'coram buildings',
#   'powis place',
#   'brunswick square',
#   'bloomsbury',
#   'lansdowne terrace',
#   'macnaghten house',
#   'rosin works',
#   'marchmont street',
#   'premier hotel',
#   'wakefield street',
#   'russell square house',
#   'russell square',
#   'nurses home',
#   'queen court',
#   "knolly's house",
#   'cartwright gardens',
#   'jenner house',
#   'royal hotel',
#   'milk bottling depot',
#   'robsart mansions',
#   'bernard mews',
#   'laundry',
#   'garage',
#   'coram street',
#   'woburn court',
#   'engineering works',
#   'cemetary (disused)',
#   'bernard street',
#   'sa hostel',
#   'selwyn house',
#   'aberdeen mansions',
#   'hunter street',
#   'robsart house',
#   'russell court',
#   'the national hospital',
#   'ward bdy',
#   'milk distributing depot',
#   'coburgh mansions',
#   'queen square',
#   'landowne terrace',
#   'woburn place',
#   'burton street',
#   'guilford street',
#   'bedford way',
#   'leigh street',
#   'whitley court',
#   'seymour house',
#   'judd street',
#   'national hotel',
#   'church hall',
#   'institute of ophthalmology',
#   'russell square hotel',
#   'mary ward settlement',
#   'handel mansions',
#   'kenton street',
#   'machnaghten house',
#   'hunter house',
#   'the hospital for sick children',
#   'school of medicine (royal free hospl)',
#   'transport depot',
#   'galsen yard',
#   'bank',
#   'grenville street'],
#  '102903928.jpg': ['dought street',
#   'guilford place',
#   'two brewers',
#   'ormond mews',
#   'calthorpe st',
#   'millman mews',
#   'the rugby',
#   'timber yard',
#   'coley street',
#   'met b bdy',
#   'rugby street',
#   'millman street',
#   'mecklenburgh',
#   'plase',
#   "john's mews",
#   "gray's inn road",
#   'kemsley house',
#   'great ormond street',
#   'long yard',
#   'pakenham street',
#   'brownlow mews',
#   'pond',
#   'the calthorpe arms',
#   'joinery works',
#   'printing works',
#   'roger street',
#   'great james st',
#   'shelter',
#   'eastman dental hospital',
#   'the sun',
#   'warehouse',
#   'wren street',
#   'phoenix place',
#   'nurses home',
#   'gough street',
#   'trinity court',
#   'langton close',
#   'tank',
#   'doughty street',
#   "gray's in road",
#   'holsworthy square',
#   'el sub sta',
#   'heathcote street',
#   'garage',
#   'school',
#   'northington street',
#   'engineering works',
#   'sunday school',
#   'ruins',
#   'hall',
#   'john street',
#   'youth hostel',
#   'ward bdy',
#   'chy',
#   'mecklenburgh st',
#   'ruin',
#   'orde hall st',
#   'guilford street',
#   'ramp',
#   'the blue lion',
#   'mytre court',
#   'joinery works1',
#   "king's mews",
#   'st andrews gardens',
#   'mecklenburgh square',
#   'north mews',
#   'elm street',
#   'london house',
#   'mecklenburgh place',
#   'met b & boro const bdy',
#   'the lamb',
#   'doughty mews',
#   "coram's fields playground",
#   'plate',
#   "lamb's conduit st",
#   "st bartholomew's church",
#   'food factory'],
#  '103199059.jpg': ['factory',
#   'priory grove',
#   'tonbridge county secondary school for girls',
#   'five oak green road',
#   'fairview',
#   'castle laundry',
#   'somerhill bungalows',
#   'judd road',
#   "tonbridge st stephen's county primary infant school",
#   'burns crescent',
#   'royal avenue',
#   'woodfield road',
#   'commercial road',
#   'tudley lane',
#   'allotment gardens',
#   'douglas road',
#   'the drive',
#   'alana',
#   "st mary's road",
#   'shalom',
#   'brionne gardens',
#   'quarry hill',
#   'pond',
#   'priory street',
#   'woodlands road',
#   'marfield cottage',
#   'almshouses',
#   'vale road',
#   'ariston',
#   'lawn road',
#   'halfar',
#   "skinner's terrace",
#   'the hermitage',
#   'jubbulpore',
#   'westbury',
#   'fairfield crescent',
#   'commercial house',
#   'lavender hill',
#   'depository',
#   'pemsbury road',
#   'allenbrae',
#   'mountfield park',
#   'waterloo place',
#   "st stephen's street",
#   "king's road",
#   'baltic road',
#   'fosse bank close',
#   'south east ward',
#   'rayleigh',
#   'narboro',
#   'wincliff road',
#   'mabeldon road',
#   'fermoy',
#   'george street',
#   'sussex road',
#   'lionel road',
#   'lodge oak lane',
#   'drain',
#   'sunnyridge',
#   'brook house',
#   'waterloo road',
#   'works',
#   'netball courts',
#   'west view',
#   'garage',
#   'tonbridge county grammar school for girls',
#   'meadow lawn',
#   'pembury road',
#   'quarry rise',
#   'hill house',
#   'goldsmid road',
#   'piggeries',
#   'trough',
#   "police station & magistrate's court",
#   'quarry gardens',
#   'ward bdy',
#   'quarry hill road',
#   'tonbridge evangelical free church',
#   'tonbridge st stephens county junior school',
#   'wideways',
#   'weald view road',
#   'ruin',
#   'hectorage road',
#   'alexandra road',
#   'tonbridge st stephens county junior sch',
#   'inglefield',
#   'springwell road',
#   'somerhill road',
#   'wield view road',
#   'tennis courts',
#   'speedway house (garage)',
#   'the judd school',
#   'priory road',
#   "police station & magistrates' court",
#   'tonbridge county secondary school for boys',
#   'woodside road',
#   'pavilion',
#   'melody',
#   'coal yard',
#   'priory wood',
#   'priory walk (fp)',
#   'meadow road',
#   'hectorage farm',
#   'depot',
#   'quarry hill parade',
#   'fosse bank girls school',
#   'tonbridge sussex road county primary school',
#   'chichester road',
#   'deakin leas',
#   "the cardinal's error",
#   'shakespeare road',
#   'surgery',
#   'tudeley lane',
#   'hectorage farm house',
#   'playing field',
#   'tonbridge london',
#   'quarry hill laundry',
#   "builder's yard",
#   'bickley road',
#   'st stephens vicarge',
#   'brook street',
#   'rural district council offices',
#   "st stephen's vicarge"],
#  '103680995.jpg': ['mabledon farm',
#   'ph',
#   'copyhold wood',
#   'reservoir',
#   'quarry hill',
#   'lodge oak lane',
#   'tonbridge',
#   'tonbridge water works co',
#   'sp',
#   'mp',
#   'ff',
#   'brick works',
#   'quarry wood',
#   'vauxhall lane',
#   'woodlands road',
#   'woodside road',
#   'little rook wood',
#   'somerhill park',
#   'high bank',
#   "may's wood",
#   'ud bdy',
#   'secondary school',
#   'pembury road',
#   'vauxhall inn',
#   'five oak green road',
#   'castle laundry',
#   'priory wood',
#   'queen victoria cottage hospital',
#   'judd road',
#   'castle hill',
#   'quarry rise',
#   'hastings',
#   'po',
#   'bournemill farm',
#   'hazel shaw',
#   'goldsmid road',
#   'priory mill',
#   'quarry hill house',
#   'bloodshots cottage',
#   'baltic road',
#   'deakin leas',
#   'little oak lodge',
#   'cs',
#   'beeches wood',
#   'quarry hill road',
#   'drayton road',
#   'lambsbank wood',
#   'southern railway',
#   'gp',
#   'girls',
#   'tudeley lane',
#   'ccs',
#   "lamb's bank cottages",
#   'weald view road',
#   'corn',
#   '3ft rh',
#   '29',
#   'lodge oak',
#   '2',
#   'rookwood cottage',
#   'the drive',
#   'und',
#   'quarry hill laundry',
#   'bp',
#   'springwell road',
#   'clinic',
#   'streamlands',
#   "st mary's road",
#   'old furze wood',
#   'ms',
#   'rook wood'],
#  '103681073.jpg': ["porter's lock",
#   "wenham's farm",
#   "eldridge's lock",
#   'tk.d.',
#   'shernden road',
#   's.f.p.',
#   'b.s',
#   'r.h.',
#   'tudeley hale',
#   'park view',
#   'whitepost plantation',
#   '3ft.r.h.',
#   'e.p.',
#   'sandling farm',
#   'hartlake road',
#   'lilley farm',
#   'und.',
#   'rats castle',
#   'upper postern',
#   'hartlake bridge',
#   'postern park',
#   'red cow (b.h.)',
#   'hartlake',
#   'roughs',
#   '3 ft.r.h.',
#   'c.r.',
#   'southern railyway',
#   'c.s.',
#   's.p.',
#   'southern railway',
#   'shernden farm',
#   'river medway',
#   'hamlet hole',
#   'sandling house',
#   "porter's",
#   "latter's farm",
#   'f.f.',
#   'def.'],
#  '103681079.jpg': ['f.p',
#   "porter's lock",
#   "eldridge's lock",
#   'f.b',
#   'c.b',
#   'high bridge',
#   '(b.h)',
#   'tudeley hale',
#   'towing',
#   'f b',
#   's p',
#   'south eastern railway',
#   'sandling farm',
#   'fp',
#   'f.f',
#   'bs',
#   'lilley farm',
#   'rats castle',
#   'upper postern',
#   's.m',
#   'postern park',
#   'def',
#   "wenhams's farm",
#   'sluice',
#   'f p',
#   'tk d',
#   'roughs',
#   'b.m',
#   'red cow',
#   'shernden farm',
#   'hamlet hole',
#   'river medway',
#   'stone',
#   'tawing path',
#   'b s',
#   'waterfall',
#   'b m',
#   'und',
#   'boat house',
#   'c.d',
#   'r.h'],
#  '103681115.jpg': ["all saints' church",
#   'reservoir',
#   'bank farm',
#   'south eastern family',
#   'church farm',
#   'crockhurst street farm',
#   'long field',
#   'burgess rough',
#   'rushputs wood',
#   'little toll',
#   'pheasent wood',
#   'somerhill park',
#   'nightingale wood',
#   'barham house',
#   'padwell wood',
#   'crockhurst street',
#   'old furze field',
#   'sheep pens',
#   'grave yard',
#   'tudeley',
#   'reservior',
#   'gate farm',
#   'glebe farm',
#   'gas works',
#   'square wood',
#   'nightingale wood2',
#   'f p',
#   'quarry',
#   'vicarage',
#   'park farm',
#   'allotment gardens',
#   'devils gill',
#   'village hall',
#   'glebe',
#   'snails bottom',
#   'reed wood',
#   'knowles bank',
#   "carpenters' arms inn",
#   'claypit rough',
#   'smithy',
#   'old quarry',
#   'somerhill',
#   'boys wood'],
#  'USGS-15-CA-brawley-e1957-s1957-p1961.jpg': ['forget-me-not canal',
#   'lotus canal',
#   'siphon',
#   'riverview cem',
#   'wilsie',
#   'tamarack ranch',
#   'pistol range',
#   'rockwood canal',
#   'san diego and  arizona eastern',
#   'imperial valley college',
#   'edgar',
#   'ross ave',
#   'bm 107',
#   'bm 115',
#   'rice drain',
#   'alder canal',
#   'bm 117',
#   'southern pacific',
#   '8th st',
#   'ben hulse sch',
#   'drive-in theater',
#   'fairgrounds',
#   'rio vista ave',
#   'labor center',
#   'lilac canal',
#   'oakley sch',
#   'mound',
#   'rose canal',
#   'hospital',
#   'pearson drain',
#   'new river',
#   'toka canal',
#   '4th st',
#   'westmorland canal',
#   'mc call drain one',
#   'eucalyptus sch',
#   'hotville',
#   'westside main canal',
#   'witter sch',
#   'central main',
#   'rubber drain',
#   'el centro naval auxiliary air station',
#   'flax canal',
#   'dolson drain',
#   'bryant canal',
#   'elder canal',
#   'westside sch',
#   'jepp trail',
#   'san diego and arizona eastern',
#   'ebony canal',
#   '10th st',
#   'purification plant',
#   'sumac lateral',
#   'mesquite drain',
#   'bm 110',
#   'memory gardens cem',
#   'trifolium drain',
#   'lantana sch',
#   'westside drain',
#   'sumac canal',
#   'bm 104',
#   'sunbeam recreation area',
#   'el centro',
#   'dahlia lateral',
#   'hidalgo sch',
#   'lavender canal',
#   'fig canal',
#   'tokay drain',
#   'central hs',
#   'thorn one canal',
#   'western ave',
#   'thistle canal',
#   'central main canal',
#   'united states department of the interior geological survey',
#   'fillaree drain',
#   'waste water disposal area',
#   'thorn canal',
#   'rip vista ave',
#   'central drain',
#   'gaging sta',
#   'holton inter-urban',
#   'bm 123',
#   'main spruce canal',
#   'main st',
#   'bm 132',
#   'naval res',
#   'evergreen cem',
#   'thistle lateral',
#   'douglas jr hs',
#   'gravel pits',
#   'timothy one drain',
#   'bullhead slough',
#   'sandal canal',
#   'rice drain one',
#   'dahlia canal',
#   'dogwood canal',
#   'naval reservation',
#   'seeley',
#   'bm 118',
#   'flume',
#   'foxglove canal',
#   'main canal',
#   'turnip canal',
#   'new spruce canal',
#   'lateral drain',
#   'eucalyptus canal',
#   'evergreen canal',
#   'imperial',
#   'date canal',
#   'thistle drain',
#   'brawley',
#   'gravel pit',
#   'stanley',
#   'fillaree canal',
#   'rose drain',
#   'pearsol drain',
#   'wt',
#   'lilac drain',
#   'reid sch',
#   'radio facility',
#   'airstrip',
#   'cotton gin',
#   'landing field',
#   'date drain',
#   'canal',
#   'newside drain',
#   'municipal airport',
#   'dixie drain one',
#   'tokay canal',
#   'labor camp',
#   'imperial cem',
#   'firing range',
#   'imperial ave',
#   'timothy drain',
#   'eucalyptus lateral',
#   'union hs',
#   'lucky',
#   'bm 78',
#   'bm 93',
#   'elder lateral',
#   'fern canal',
#   'newside canal',
#   'tuberose canal',
#   'bm-40',
#   'fig drain',
#   'po',
#   'adams ave',
#   'elm canal',
#   'salt creek slough',
#   'palm ave',
#   'dixie drain',
#   'sunbeam lake',
#   'silsbee sch',
#   'mc call drain',
#   'bm 111',
#   'dandelion canal',
#   'best canal',
#   'westside main sandal',
#   'sugar refinery',
#   'main ave',
#   'imperial valley',
#   'pioneer memorial hospital',
#   'anza',
#   '6th st',
#   'brawley quandrangle california-imperial co. 15 minute series (topographic)',
#   'sewage disposal'],
#  'USGS-15-CA-capesanmartin-e1921-s1917.jpg': ['plaskett creek',
#   'bald top',
#   'bird rock',
#   'devils',
#   'dutra place',
#   'contour interval off shore 50 feet',
#   'coast',
#   'w r hearst',
#   'lower coast trail',
#   'evans bros',
#   'control by us coast and geodetic survey',
#   'junipero serra',
#   'ragged pt',
#   'melville mine',
#   'buclimo mine',
#   'burro mtn',
#   'king city',
#   '4 miles',
#   'mill',
#   'old cruikshank ranch',
#   'squirrel spr',
#   'datum is mean lower low water',
#   'villa',
#   'sliek rock',
#   'polar school',
#   'estrada',
#   'san luis obispo co',
#   'cape san martin',
#   'san miguelito',
#   'mt mars',
#   'plaskett rock',
#   'anthony',
#   'north',
#   'sans',
#   'underwater contours by us coast and geodetic surve',
#   'mine',
#   'pacific ocean',
#   'upper',
#   'willow',
#   'national forest',
#   'cape san martin quadrangle',
#   'fork',
#   'creek',
#   '6 feet above mean lower low water at cape san mart',
#   'rb marshall chief geographerl',
#   'surveyed in 1917',
#   'secretary',
#   'river',
#   'stony',
#   'cow camp',
#   'nacimiento school',
#   'c a stonesifer and cwh nessler',
#   'scale',
#   'south',
#   'topography',
#   'geo r davis, geographer in charge',
#   'nigger fark',
#   'prewitt',
#   'lucia',
#   'shore line is the margin of water at mean high tid',
#   'milpitas',
#   'white rock',
#   'syemore spring',
#   'upper coast trail',
#   'woods',
#   'round spring',
#   'south fork',
#   'little burros creek',
#   'gonzales',
#   'lf biggs and rc seitz',
#   'old jones raneli',
#   'silver peak',
#   'krenkels ranch',
#   'wild cattle cr',
#   'syeamore spring',
#   'datum is mean sea level',
#   'piedras blancas',
#   'king camp',
#   'windy',
#   'u.s. geological survey',
#   'chris flood creek',
#   'stony valley',
#   'jones mtn',
#   'basket spring',
#   'dutra',
#   'lion peak',
#   'canyon',
#   'piedra blanca',
#   'school spring',
#   'house',
#   'sawmill',
#   'gorda school',
#   'lower coast',
#   'plaskett',
#   'abandoned',
#   'redwood gulch',
#   'chalk peak',
#   'san martin top',
#   'gorda',
#   'gorda mine',
#   '5 kilometers',
#   'bryson',
#   'kirk',
#   'san carpoforo',
#   'san miguel',
#   'three peaks',
#   'montery co',
#   'calizona mine',
#   'brush',
#   'trail',
#   'alderpeak',
#   'contour interval on land 50 feet',
#   'buckeye spring',
#   'california',
#   'george otis smith',
#   'topography by us coast and geodetic survey',
#   'director',
#   'nacimiento',
#   '1921',
#   'los burros',
#   'rangersta',
#   'salmon cone',
#   'rb marshall chief geographer',
#   'ray evans ranch',
#   'wagner creek',
#   'polyconic projection north american datum',
#   'santa barbara',
#   'salmon',
#   'alder creek',
#   'santa lucia range',
#   'albert b fall',
#   'north fork',
#   'edition of 1921',
#   'foremans headquarters',
#   'department of the interior',
#   'soda spring'],
#  'USGS-15-CA-paloalto-e1899-s1895-rp1911.jpg': ['george otis smith, director',
#   'devils slough',
#   'castro',
#   'sausal cr.',
#   't. 6 s.',
#   'r.i.w.',
#   'r. u. goode geographer in charge',
#   'table mountain',
#   'fairoaks',
#   'eues creek',
#   'san francisquito',
#   'southern pacific',
#   'rinconada del arroyo de san francisquito',
#   'r. 4 w.',
#   'santa cruz',
#   'san jose',
#   'jagel slough',
#   'alameda co.',
#   'menlo park',
#   'edition of mar.1899 reprinted may 1911.',
#   'calabazas creek',
#   'canada de raymundo',
#   'marshall',
#   'corte de madera',
#   'west side',
#   'saratoga',
#   'bear cr.',
#   "122°15'",
#   'redwood slough',
#   'triangulation by u. s. coast and geodetic survey',
#   't. 8 s.',
#   'guadalupe slough',
#   'los traneos creek',
#   'campbell cr.',
#   'contour inverval 25 feet',
#   'san antonio creek',
#   'pastoria de las borregas',
#   'mountain view',
#   'martin cr.',
#   'pulgas',
#   't. 7 s.',
#   'topography',
#   'pescadero creek',
#   'quito',
#   'madera creek',
#   'coyote river',
#   'permanente creek',
#   'potrero pt.',
#   'alpine creek',
#   'mayfield',
#   'mindego hill',
#   'portola',
#   'san mateo',
#   'martin cr',
#   'old mountain view',
#   'cordilleras cr.',
#   'cooley landing',
#   'alviso slough',
#   'monterey line',
#   'redwood',
#   'san antonio',
#   'stanford university',
#   'congress springs',
#   'henry gannett chief topographer',
#   'black mountain',
#   'u.s. geological survey',
#   'azule springs',
#   'la purisma concepcion',
#   'peters creek',
#   'san francisquito creek',
#   'calaveras pt.',
#   'el corte de madera',
#   'boundary line',
#   'surveyed in 1895',
#   'miles',
#   'bm',
#   "37°30'",
#   'slate creek',
#   'mountain view ldg.',
#   'langley hill',
#   'engraved aug. 1897 by u.s.g.s.',
#   'palo alto',
#   'stevens creek',
#   'west point slough',
#   'haywards',
#   'murphy',
#   'posolmi',
#   'canada del corte de madera',
#   'mowry slough',
#   'topography by r.b. marshall and u.s.c. and g.s.',
#   '5428',
#   'corte de madera creek',
#   'ravenwood slough',
#   "122°00'",
#   'mindego creek',
#   'santa clara co.',
#   'u.s.c. & g.s.',
#   'george otis smith director',
#   'kilometers',
#   'california',
#   'rincon de san francisquito',
#   'catholic university',
#   'san francisco bay',
#   'oil creek',
#   'guth landing',
#   'searsville lake',
#   'san mateo co.',
#   'monte bello ridge',
#   'pleasanton',
#   'palo alto quadrangle',
#   "37°15'",
#   'jagel landing',
#   'r. 2 w.',
#   'san francisuito creek',
#   'sea lake',
#   'santa cruz co.'],
#  'USGS-15-CA-sanfrancisco-e1899-s1892-rp1911.jpg': ['san francisco & north pacific r.r.',
#   'mile rocks',
#   'red rock',
#   'pinole ridge',
#   'livermore line',
#   'telegraph hill',
#   'yellow bluff',
#   'sausalito pt.',
#   'san quentin pt.',
#   'san pablo',
#   'university of california',
#   'punta de quentin',
#   'r.r.',
#   'southern pacific',
#   'castro pt.',
#   'lake merritt',
#   'pt. diablo',
#   'cemetery',
#   'barrett',
#   'richmond pt.',
#   'steamboat pt.',
#   'alameda co.',
#   'golden gate park',
#   'brooks id.',
#   'military reservation',
#   'lobos creek',
#   'alameda',
#   'san pablo ridge',
#   'angel id.',
#   'marin peninsula',
#   'hospital cove',
#   'bluff pt.',
#   'cerrito',
#   'potrero nuevo',
#   'stuart pt.',
#   'raccoon strait',
#   'flemings pt.',
#   'corte de madera',
#   'deep water channel',
#   'san pedro pt.',
#   'san pablo sta.',
#   'north pt.',
#   'strawberry creek',
#   'rincon pt.',
#   'dwight way',
#   'shag rock',
#   'pt. lobos',
#   '(haywards)',
#   'simpton pt.',
#   'pinole',
#   'san rafael cr.',
#   'alcatraz id.',
#   'strawberry hill',
#   'tamalpais',
#   'presidio',
#   'black pt.',
#   'v & d paralia',
#   'cerrito creek',
#   'contra costa co.',
#   'san antonio creek',
#   'san quentin',
#   'adeline',
#   'u.s. geological survey george otis smith, director',
#   'golden gate',
#   'pinole creek',
#   'mission rock',
#   'oakland harbor',
#   'tiburon peninsula',
#   'cone rock',
#   'chauncey pt.',
#   'oakland',
#   'topography by u.s.c. and g.s., u.s. eng. corps, city surveys and by r.h. chapman. r.b. marshall and w.h. otis. surveyed in 1892-93-94.',
#   'gibbon pt.',
#   'temescal',
#   'california and nevada',
#   'marin ids.',
#   'r4w',
#   'sobrante',
#   'engraved aug. 1895 by u.s.g.s.',
#   'fort pt.',
#   'horseshoe bay',
#   'lone mt.',
#   'richardson bay',
#   'potrero pt.',
#   'topography (napa 1/125000)',
#   'emery',
#   'mountain lake',
#   'noble',
#   'lorin',
#   'cem.',
#   'pueblo lands of san francisco',
#   'shell mound',
#   'seal rocks',
#   's. p. r. r. narrow gauge',
#   'fort mason',
#   'san antonio',
#   'datum is mean sea level',
#   'potrero san pablo',
#   'santa margarita y las gallinas',
#   'blunt pt.',
#   'sausalito',
#   'oakland mole',
#   'highland',
#   'boundary line',
#   'castro creek',
#   'needles',
#   'l.s.s.',
#   'san francisco',
#   'san pablo bay',
#   'berkeley hills',
#   'n.p. coast r.r.',
#   'sixteenth st.',
#   '(napa 1/125000)',
#   'sutro crest',
#   'sobrante ridge',
#   '(san mateo) scale 1/62500',
#   'west berkeley',
#   'cliff house',
#   'n.p. coast r.r',
#   'the sisters',
#   'north berkeley',
#   'molate pt.',
#   't2n',
#   's. p. r. r.',
#   "37°45' 122°15'",
#   'california pt.',
#   'san miguel',
#   'light',
#   'san pablo creek',
#   'arch rock',
#   'campbell pt.',
#   'the brothers',
#   'berkeley',
#   'san pablo pt.',
#   'reference map file history department los angeles public library 630 west fifth street los angeles calif 90007',
#   'kilometers',
#   'lime pt.',
#   'knox pt.',
#   'pt. tiburon',
#   'contour interval 25 feet',
#   'a.h. thompson, geographer. willard d. johnson, topographer in charge. triangulation by u.s. coast and geodetic survet',
#   'san francisco co. and city',
#   'ashby ave',
#   'cordonices creek',
#   'cavallo pt.',
#   "122°30' 38°00'",
#   'california san francisco quadrangle',
#   'belvedere',
#   'san francisco bay',
#   'u.s. marine hospital',
#   'strawberry pt.',
#   'stege',
#   'isabel pt.',
#   's.p.r.r.',
#   'san pablo strait',
#   'marin co.',
#   'goat id.',
#   'giant',
#   'peralta',
#   'edition of feb. 1899, reprinted sept. 1911',
#   'wildcat creek',
#   'quarry pt.',
#   'peninsula pt.'],
#  'USGS-30-CA-dardanelles-e1898-s1891-rp1912.jpg': ['red pk',
#   'leavitt meadow2',
#   'whitecliff pk',
#   'piute cr',
#   'craig pk',
#   'north fork stanislaus river',
#   'south fork stanislaus river',
#   'eagle meadow',
#   'tiltill mountain',
#   'cow creek',
#   'henry pk',
#   'chittenden pk',
#   'alpine co',
#   'lost cannon pk',
#   'west fork',
#   'upper relief valley',
#   'iceberg meadow',
#   'grizzly pk',
#   'pickle meadow',
#   'mill creek',
#   'edna lake',
#   'grouse creek',
#   'weset walker river',
#   'tuolumne co',
#   'andrews pk',
#   'fish valley',
#   'eleanor cr',
#   'brightman flat',
#   'emigrant meadows',
#   'mercur pk',
#   'night cap',
#   'kerrick canyon',
#   'bald pk',
#   'twin lakes',
#   'lily lake',
#   'summit meadow',
#   'white canyon',
#   'kibbie ridge',
#   'wilmer lake',
#   'disaster creek',
#   'silver king cr',
#   'kibbie lake',
#   'bearup lake',
#   'keyes pk',
#   'frog creek',
#   'clark fork',
#   'arnot pk',
#   'dorothy lake',
#   'golden canyon',
#   'kennedy lake',
#   'stanislaus pk',
#   'tilden canyon',
#   'disaster pk',
#   'falls cr',
#   'leavitt pk',
#   'yosemite national park',
#   'bond pass',
#   'macomb ridge',
#   'fish valley pk',
#   'benson lake',
#   'sonora pk',
#   'lake vernon',
#   'east fork',
#   'thompson canyon',
#   'sand flat',
#   'bigelow pk',
#   'bear valley',
#   'forsyth pk',
#   'stubblefield canyon',
#   'cherry ridge',
#   'reed creek',
#   'jawbone cr',
#   'lily creek',
#   'kibbie creek',
#   'iceberg pk',
#   'edith lake',
#   'gillett mt',
#   'rancheria creek',
#   'emigrant lake',
#   'granite dome',
#   'white mr',
#   'herring creek',
#   'snow pk',
#   'sonora pass',
#   'lost cannon creek',
#   'michie pk',
#   'white mt.',
#   'east flange rock',
#   'the dardanelles',
#   'burst lake',
#   'moraine ridge',
#   'wells pk',
#   'price pk',
#   'jack main canyon',
#   'mono co',
#   'bull run pk',
#   'lily cr',
#   'tilden lake',
#   'wolf cr',
#   'stanislaus national forest',
#   'balk pk.',
#   'schofield pk',
#   'baker station',
#   '(yosemite)',
#   'carson river',
#   'flora lake',
#   'kennedy pk',
#   'highland reservoir',
#   'buelah lake',
#   'sierra nevada',
#   'whitecliff',
#   'highland lake',
#   'bull run cr',
#   'grace meadow',
#   'helen lake',
#   'mccormick creek',
#   'arndt lake',
#   'tuolomne co',
#   'eleanor lake',
#   'middle fork river',
#   'folger pk',
#   'relief creek',
#   'deadman creek',
#   'bartlett pk',
#   'tuolmne co',
#   'boundary line',
#   'pacific cr',
#   'stanislaus river',
#   'bailey ridge',
#   'tower pk',
#   'antelope pk',
#   'claver river',
#   'eagle creek',
#   'seavey pass',
#   'dardanelles cone',
#   'cherry cr',
#   'mono national forest',
#   'tiltill cr',
#   'acker pk',
#   'duck cr',
#   'dardanelles creek',
#   'arnot creek',
#   'beulah lake',
#   'east canyon river',
#   'highland creek',
#   'leavitt creek',
#   'walker river',
#   'laurel lake',
#   'breeze creek',
#   'relief pk',
#   'eureka valley',
#   'boulder cr',
#   'mary lake',
#   'the iceberg',
#   '(pyramid peak)',
#   'stanislaus',
#   'nance pk',
#   'richardson pk',
#   'gertrude lake',
#   'castle rock',
#   'branigan lake',
#   'belle meadow',
#   'hyatt lake',
#   'highland resevoir',
#   'piute mt',
#   'anna lake',
#   'silver creek',
#   'the dardanelle',
#   'duck lake',
#   'mahan pk',
#   'trout cr',
#   'kendrick pk',
#   'leavitt meadow',
#   'huckleberry lake',
#   'clavey river',
#   '(bridgeport)',
#   'us geological survey geroge otis smith, director',
#   'ehrnbeck pk',
#   'cascade creek',
#   'north fork',
#   'cherry creek canyon',
#   'wheeler pk',
#   'relief valley',
#   'eagle pk',
#   'reynolds creek',
#   'haystack pk',
#   'cooper meadow',
#   'poison valley',
#   'niagra creek'],
#  'USGS-30-CA-holtville-e1907-s1905-rp1946.jpg': ['deal ditch',
#   'no 1',
#   'sunset spr',
#   'holt ditch',
#   'ruthven',
#   'baja california',
#   'alamo river',
#   'oat canal',
#   'united states',
#   'main canal',
#   'pampas ditch',
#   'sea level',
#   'sand hills',
#   'pampas canal',
#   'hickory ditch',
#   'deer peak',
#   'calexico',
#   'french lake',
#   'pomelo ditch',
#   'california',
#   'holtville',
#   'boundary line',
#   'california (imperial county) holtville quantrangle',
#   'brooks switch',
#   'united states department of the interior geological survey',
#   'palm ditch',
#   'redwood ditch',
#   'no 5',
#   'plum ditch',
#   'sf and no line',
#   'rubber ditch',
#   'no 7',
#   'palmetto ditch',
#   'peach ditch',
#   'gleason switch',
#   'mexico',
#   'glamis',
#   'no 3',
#   'quince ditch',
#   'hemlock ditch',
#   'holt ditch no 6',
#   'holton interurban',
#   'alamitos ditch',
#   'pear ditch',
#   'sprr',
#   'dear peak',
#   'brice siding',
#   '100 feet below sea level',
#   '(salton sink)'],
#  'USGS-30-CA-indiospecial-e1904-s1901-rp1910.jpg': ['hellhole',
#   'old nicholas canyon',
#   'omstott creek',
#   'seventeen palms',
#   't. 6 s.',
#   'la mesa',
#   "33°15'",
#   'grapevine creek',
#   'sugarloaf mt.',
#   'cabezon indian res.',
#   'santa rosa',
#   'magnesia spring',
#   'coyote mtn.',
#   'r. 9 e.',
#   'sheep mt.',
#   't. 9 s.',
#   'santa rosa mountains',
#   'thermal',
#   'imperial co.',
#   'augustin indian res.',
#   'engraved oct 1903 by u.s.g.s.',
#   "40'",
#   'toro peak',
#   'barton canyon',
#   'black hill',
#   'r. 6 e.',
#   'collins valley',
#   'ebbens creek',
#   'contour interval 100 feet.',
#   't. 8 s.',
#   'carrizo creek',
#   'toro indian reservation',
#   'pinyon alta flat',
#   'tahquitz canyon',
#   'haystack mt.',
#   'riverside co',
#   'asbestos spring',
#   'approximate mean declination 1902',
#   'alamo bonito',
#   'agua alta canyon',
#   'indio special',
#   't. 7 s.',
#   'datum is mean sea level.',
#   'asbestos mountain',
#   'scale',
#   'edition of april 1904, reprinted mar. 1910',
#   'tahquitx creek',
#   'ramona',
#   't. 4 s.',
#   'rockhouse canyon',
#   'magnesia spring canyon',
#   'borego valley',
#   'bradley canyon',
#   'coachella',
#   'devil canyon',
#   'san ysidro mtn.',
#   'martinez',
#   'fish springs',
#   'r. 8 e.',
#   'palm canyon',
#   'cat creek',
#   'pinyon flat',
#   'indio',
#   'little pinyon flat',
#   'san diego co.',
#   'horsethief creek',
#   'garnet queen mine',
#   "116°00'",
#   'ramon creek',
#   'virgin spring',
#   'martinez canyon',
#   'coyote creek',
#   'indian well',
#   'old santa rosa',
#   'casa de cuerva',
#   'dead indian creek',
#   "116°30'",
#   'dry camp',
#   'agua dulce',
#   'clark well',
#   'mission creek',
#   'cathedral canyon',
#   'martinez mt.',
#   'mecca',
#   'true north',
#   'agua alta spring',
#   'magnetic north',
#   'san jacinto',
#   'salton basin',
#   'r.u. goods, geographer in charge. triangulation by e.t. perkins and a.j. sylvester toppgraphy by a. i. oliver and r. s. oliver. surveyed in 1901.',
#   'guadalupe creek',
#   'whitewater river',
#   'potrero spring',
#   'san diego co',
#   't. 10 s.',
#   'black rabbit canyon',
#   'southern pacific r.r.',
#   'coachella valley',
#   'clark lake',
#   'cleveland national forest',
#   'toro',
#   'thousand palms canyon',
#   'dos palmos spring',
#   'deep canyon',
#   'cactus spring',
#   'asbestos mine',
#   't. 5 s.',
#   'sheep creek',
#   'figtree john',
#   'myoma',
#   "20'",
#   'i.r.',
#   'indio mt.',
#   'riverside co.',
#   'mortmere',
#   'rabbit peak',
#   'toro canyon',
#   'rock canyon',
#   "30'",
#   'b.m.',
#   'diagram of township',
#   'ebbens valley',
#   'santa rosa mt.'],
#  'USGS-30-CA-lompoc-e1943-s1903-ap1941-rv1941.jpg': ['sisquoc',
#   'cañada del los coches',
#   'cañada san onofre',
#   'cañada de la vina',
#   'war department corps of engineers, u.s. army`',
#   'arroyo hondo',
#   'cañada de las encinas',
#   'san lucas cr',
#   'casmalia hills',
#   'cañada de las cruces',
#   '1943',
#   'graciosa canyon',
#   'san antonio valley',
#   'llanito cr',
#   'cañada del gato',
#   'garey',
#   'state route',
#   'tepusquet sch',
#   'santa rita sch',
#   'bicknell',
#   'cañada del comasa',
#   'los olivos',
#   'mission la purisima',
#   'graciosa ridge',
#   'santa cora cr',
#   'rspada creek',
#   'southern pacific',
#   'santa barbara channel',
#   'horseshoe spring',
#   '(branch mtn.)',
#   'yridisis cr',
#   'cañada de santa rosa',
#   'cañada del corral',
#   'el callejon cr',
#   'pine canyon',
#   'cañada de la laguna',
#   'labrea creek',
#   'gaviota',
#   'cañada del agua caliente',
#   'lampoc quadrangle grid zone " g:',
#   'jalama creek',
#   '(branch mtn)',
#   '1',
#   'flores canyon',
#   'alcatraz',
#   'cañada omentero',
#   'gaviota beach',
#   'san julian sch',
#   'army map service us army washington dc 104893',
#   'cañada del agua amarga',
#   'round corral canyon',
#   'zaca lake',
#   'bone mtn',
#   'careaga canyon',
#   'horse gultch',
#   'cañada del capitan',
#   'solomon canyon',
#   'san luis obispo',
#   'palmer',
#   'refugio pass',
#   'los padres national forest',
#   'comtour interval 100 feet',
#   'cañada de los palos blancos',
#   'restricted lompoc, calif.',
#   'restricted california santa barbara county lompoc quadrangle grid zone "g"',
#   'alamo pintado creek',
#   'san miguelito creek',
#   'manzanita mtn',
#   'santa maria canyon',
#   'los alamos',
#   'sacate',
#   'gaviota pk',
#   'cuaslui cr',
#   'cañada de la brea',
#   'san antonio creek',
#   'mt solomon',
#   'zaca pk',
#   'jalama sch',
#   'orcutt',
#   'cuyama river',
#   'cañada de la puenta',
#   'cañada de las flores',
#   'cañada de santa ynez',
#   'birbent creek',
#   'buellton',
#   'road classifications',
#   'tunnel canyon',
#   'cañada del regugio',
#   'east spring canyon',
#   'bee rock canyon',
#   'stag canyon',
#   'cañada arena',
#   'nojuqio falls co park',
#   'gaviota canyon',
#   'olive sch',
#   'government pt',
#   'maricopa 77.5 mi.',
#   'cañada de los coches',
#   'suey creek',
#   'colson fork',
#   'cañada de la posta',
#   'cañada del cojo',
#   'careaga sch',
#   'lampoc',
#   'ballard',
#   'chiquero sch',
#   'purisima hills',
#   'gasper creek',
#   'sacate canyon',
#   'purisima canyon',
#   'south fork',
#   'tepusquet pk',
#   'cañada de las calaveras',
#   'miguelito park',
#   'u.s. route',
#   'redrock mtn',
#   'tajiguas creek',
#   'los alames creek',
#   'bear canyon',
#   'barrel spring',
#   'approximate mean declination 1942 annual magnetic change 15" change',
#   'harris canyon',
#   'arroyo de san augustin',
#   'more than two lands indicated by note with tick at point of change.',
#   'datum is mean sea level',
#   'capitan',
#   'gato',
#   'roadamite',
#   'asphaltum creek',
#   'kerry canyon',
#   'escondido creek',
#   'restricted',
#   'san francisco 266 mi.',
#   'de[endable hard surface, heavy duty road.',
#   'jalama',
#   'cañnada de la posta',
#   'pt conception',
#   '(san luis)',
#   'tepusquet creek',
#   'san rafael mountains',
#   'san augustin',
#   'cañada botella',
#   'cañada laguna seca',
#   'cañada venadito',
#   'horeseshoe spring',
#   'midland sch',
#   'guadalupe 4 mi.',
#   'santa maria',
#   'el jaro creek',
#   'webber ranch',
#   'san luis obispo 29 mi.',
#   'los amoles creek',
#   'arroyo de los alamos',
#   'cañada del refugio',
#   'road data 1942',
#   '(nipoma)',
#   'suey sch',
#   'true north',
#   'harris',
#   'la hoya creek',
#   'magnetic north',
#   'santa rosa park',
#   'san antonio road',
#   '(mckittrick)',
#   'chiquero',
#   'salispuedes creek',
#   'bakersfield 119.5 mi.',
#   'concepcion',
#   'loose surface graded, dry weather road.',
#   'rattlesnake canyon',
#   'sisquoc river',
#   'nojoqui falls co park',
#   'drum canyon',
#   'cañada de molino',
#   'cañada de los alisos',
#   'santa rosa hills',
#   'surf 7.7 mi.',
#   'howard canyon',
#   'santa maria valley railroad',
#   'lompoc hills',
#   'crawford canyon',
#   'santa aqueda creek',
#   'santa ynez mission',
#   'secondary, hard surface, all weather road.',
#   'santa barbara county',
#   'wildhorse canyon',
#   'barrel springs',
#   'alisal creek',
#   'santa ynez',
#   'foxen canyon',
#   'asphaltum mine',
#   'righetti road',
#   'oak mtn',
#   'horse gulch',
#   'orella',
#   'nojoqui creek',
#   'cañada del agua',
#   'guadalupe 8.5 mi.',
#   'los alamos valley',
#   'los coches mtn',
#   'county',
#   'cañada de las cruxes',
#   'smith canyon',
#   'figueroa creek',
#   '(guadalupe)',
#   'santa ynez river',
#   'los angeles 115 mi.',
#   'santa ynez mountains',
#   'santa rita hills',
#   'california',
#   'lookout mtn',
#   'santa maria valley',
#   'buckhorn canyon',
#   'cañada de santa anita',
#   'arroyo el bulito',
#   'tajiguas',
#   'cuarta canyon',
#   'santa maria river',
#   'santa barbara',
#   'santa lucia canyon',
#   'goodchild ranch',
#   'santa rita valley',
#   'cebada canyon',
#   'solomon hills',
#   'santa barbara 17 mi.',
#   'unimproved road.',
#   'north fork',
#   'ballard creek',
#   'drake',
#   'olivera canyon',
#   'la zaca creek',
#   'arroyo quemado',
#   'lion canyon',
#   'las cruces',
#   'solvang'],
#  'USGS-30-CA-sanpedro-e1943-rv1944.jpg': ['los alamitos',
#   'rio hondo',
#   'reservoir',
#   'watcharn basin',
#   'clifton',
#   'south western lac & c',
#   'inglewood park cem',
#   'point fermin',
#   'atlantic blvd',
#   'first edition (ams 1) 1943; revised (ams 2), 1944. prepared under the direction of the chie fof engineers, u.s. army, by army map service, san antonio branch, 1943. compiled from u.s.g.s. quadrangles 1923-1925, tactical maps by 29th engineers, u.s. army,',
#   'gardena',
#   'los angeles harbor',
#   'san pedro hills',
#   'bm 101',
#   'loyola university',
#   'southern pacific',
#   'portuguese point',
#   'compton',
#   'hwy. 99',
#   '6',
#   'santa monica bay',
#   'bolso bay',
#   'dominguez  channel',
#   '16',
#   "33°30' 118°00'",
#   'vultee field',
#   "1180 40' 1170",
#   'bixby',
#   'calif. 6 1 460 000',
#   'oil field',
#   'santa catalina island no1 1:25,000',
#   '1300',
#   '1320 000 calif. 6',
#   '101 6',
#   'alameda street',
#   'chica 68',
#   'flagstaff',
#   'whites point',
#   'dycer airport',
#   '4 lane',
#   'california san pedro quadrangle grid zone "g\'',
#   'no 5',
#   'calif. 5',
#   'barber city',
#   'watson crossing',
#   'airport',
#   'san gabriel river',
#   'ocean park pier',
#   'los angeles river',
#   'norwalk',
#   'point vincente',
#   'union pacific',
#   'studebaker',
#   'los angeles 3.0 mi',
#   'flat rock point',
#   'orange co',
#   'santa ana branch',
#   'pomona 1:62.500',
#   'long point',
#   'santa monica 2 mi.',
#   'capistrano',
#   'wilmington',
#   'east basin chan',
#   'dominguez',
#   'los palos verdes',
#   'terminal island',
#   'california san pedro quadrangle grid zone "g"',
#   'sewer outlet pier',
#   '26',
#   'standard oil co. pier',
#   'ballona lagoon',
#   'up',
#   'bm 62',
#   'pacific ocean',
#   '1.0 mi.',
#   'seal beach airport',
#   'inspiration point',
#   'corona',
#   '1349',
#   "33°30' 118°30'",
#   "1200 50' 1190",
#   '1260 000 yards',
#   'atchinson topeka and santa fe',
#   '101 a',
#   'rocky point',
#   'fish harbor',
#   'slater ave',
#   'dominguez hill',
#   '3 lane',
#   'radio sta',
#   'torrance',
#   'laguna',
#   'pasadena 12 mi.',
#   'fullerton 12 mi.',
#   'montebello 4.0 mi.',
#   '11',
#   'santa monica',
#   'los angeles city hall 12. mi culver city 2 mi.',
#   'topanga beach 8 mi.',
#   'la mirada',
#   'los angeles nw base 128 usc & gs',
#   'workman hill',
#   '1941. control by u.s.c. & g.s. polyconic projection, north american datum, 1927.',
#   'san pedro nw base usc & gs',
#   'los angeles and san diego branch',
#   '101',
#   'dominguez reservoir',
#   'obed bell sta',
#   'perry',
#   '57',
#   'oil tanks',
#   'los angeles co',
#   '18',
#   'lac of c lafc',
#   'dominguez junction',
#   'long beach',
#   'palos verdes hills',
#   'san pedro hill',
#   'bolsa ave',
#   "grid declination 1°40' or 30 mils e.",
#   "1270 20'",
#   'central airport',
#   'bell',
#   'calif. 5 1 860 000',
#   'sunset blvd. 7 mi.',
#   'bixby slough',
#   'lennox',
#   '12° 13° 14° 15° 16°',
#   'san pedro',
#   'inglewood',
#   'dominguez memorial seminary',
#   'los angeles',
#   'hot springs',
#   'los angeles 4 mi.',
#   'breakwater',
#   'venice pier',
#   'the last three digits of the grid numbers are omitted the state grids are indicated for california zone 6 by ..... ticks. for zones by _._ ticks outside the neat line at 200000 foot intervals note:  officers using this map will mark hereon corrections',
#   "1280 10' 1290",
#   'kellys airport',
#   'turning basin',
#   'venice',
#   'army map service. u.s. army. washington d.c. 112576 9/44 sx 1943',
#   'lynwood',
#   '500 000 calif. 6',
#   'san pedro 1479 usc & gs',
#   'sp',
#   'el segundo',
#   'santa fe springs',
#   'san pedro, calif. n330-w11800/30',
#   'huntington beach',
#   'sunset beach',
#   'byp 101',
#   'hwy. 99 1.0 mi. buena vista park 2 mi.',
#   'alt 101',
#   'golden west street',
#   'artesia',
#   'restricted',
#   'santa fe springs sta',
#   'bm 57',
#   '22',
#   'coyote creek',
#   'calumos',
#   'reservation point',
#   '345',
#   'culver city airport',
#   'long beach breakwater',
#   'westminster',
#   'contour interval 100 feet datum is mean sea level ten thousand yard grid computed from "grid system for progressive maps in the u.s." zone g. u.s.c. & g.s. special publication no. 59',
#   'dominguez  hill usc & gs',
#   '1322',
#   "118°00'",
#   'lunada bay',
#   'bellflower',
#   'bm 24',
#   'fruitland',
#   'fulton wells',
#   'del rey auxilliary lac & c',
#   'use diagram only to obtain numerical values. to determine magnetic north line connect the pivot point "p" on the south edge of the map with the value of the angle between the grid and magnetic north, as plotted on the degree scale at the north edge of th',
#   'hawthorne',
#   'workman',
#   'compton airport',
#   'hollydale',
#   'clearwater',
#   'centinela creek',
#   'hog',
#   'east san pedro',
#   'bm',
#   'malaga cove',
#   'santa ana 7.0 mi.',
#   'los nietos',
#   '180 000',
#   'pasadena 1:62,500',
#   'edison intake pier',
#   'downey',
#   "approximate mean declination 1943 for center of sheet annual magnetic change 1' decrease",
#   'newport beach 4.9 mi. san diego 89.9 mi.',
#   'calif. 5 2 000 000',
#   'nigger slough',
#   "grid declination 1°23' or 25 mils e",
#   'bm 157',
#   'bm 119',
#   '35',
#   'bm 45',
#   'lomita',
#   '1210 660 000 calif. 6',
#   'anaheim 5 mi.',
#   'san pedro bay',
#   'bluff cove',
#   'dawson',
#   'santa monica 1:62,500',
#   'dominguez channel',
#   'boulon lake',
#   'bm 43',
#   '910',
#   'aero corp of calif field',
#   '14',
#   'mormon',
#   'harbor city',
#   'bm 48',
#   'huntington park',
#   'south clearwater',
#   'ballona creek',
#   'gould lane',
#   'and additions which come to their attention and mail direct to the chief of engineers, washington d.c.',
#   'manhattan beach',
#   'hughes airport',
#   'redondo beach',
#   'watts',
#   'war department corps of engineers, u.s. army',
#   'bm 113',
#   'pacific electric',
#   '19',
#   'san pedro channel',
#   'whittier',
#   'lakewood village',
#   'monte bello',
#   'el nido',
#   'santa monica pier',
#   '10',
#   'thenard junction',
#   '201',
#   'strawberry park',
#   'seal beach',
#   'san pedro se base usc & gs',
#   'hermosa beach',
#   'compton cr',
#   'west basin',
#   'culver blvd',
#   "118°30' 34°00'",
#   'athens',
#   'anaheim creek',
#   'north long beach',
#   "34°00'",
#   'baldwin hills',
#   '402',
#   'springdale street',
#   'reservoir hill',
#   '364',
#   'rs',
#   '409',
#   'calif. 5 1160 000 yards',
#   'santa catalina island no2 1:25,00',
#   'west beach no 3 usc & gs',
#   'slip no',
#   '367',
#   'lawndale',
#   'east whittier',
#   'power plant',
#   'carmenita',
#   'walteria',
#   'first edition-ams 2',
#   'south gate',
#   'bolsa chica road',
#   'dominguez chanel',
#   'los angeles 6 mi.',
#   'portuguese bend',
#   'west breakwater',
#   'willowbrook',
#   'rivera',
#   'anaheim bay'],
#  'USGS-60-CA-alturas-e1892-rp1904.jpg': ['pine creek',
#   'south fork pit river',
#   'delta lake',
#   'steele meadow',
#   'twelve mile creek',
#   'spring valley',
#   'reprinted dec. 1904',
#   'timbered mt',
#   'beaver creek',
#   'long valley',
#   'honey lake',
#   'rock creek',
#   'cottonwood creek',
#   'black canyon',
#   'eagleville',
#   "bare's creek",
#   'bidwell peak',
#   'clear lake',
#   'south fork willow creek',
#   'raider creek',
#   'boyd hot spring',
#   'lake',
#   'boles meadow',
#   'eagle peak',
#   'edition of mar. 1892',
#   'snake lake',
#   'tule marsh',
#   'adin',
#   'lassen',
#   'nevada',
#   'big valley',
#   'warren peak',
#   'cedar peak',
#   'north fork willow creek',
#   'west valley canyon',
#   'ash creek',
#   'scheffer mt',
#   'hayden hill',
#   'upper lake',
#   'davis creek',
#   'cow head lake',
#   'weed valley',
#   'tuledad canyon',
#   'eight mile creek',
#   'old indian villages',
#   'willow creek meadow',
#   'scale',
#   'lower lake',
#   'fandango creek',
#   'swedrengen creek',
#   'modoc lava bed',
#   'sugar hill',
#   '2',
#   'dry creek',
#   'myrtle creek',
#   'pot hole meadow',
#   'warner mountains',
#   'jospeh creek',
#   'ricksecker 1885',
#   'wheeler survey',
#   'blue lake',
#   'round valley',
#   'parker creek',
#   'north fork pit river',
#   'u.s. geological survey',
#   'lake annie',
#   'canby',
#   'fairchild meadow',
#   'south fork peak',
#   'fort bidwell',
#   'fletcher creek',
#   'goose lake',
#   'surprise valley',
#   'boundary line',
#   'fitzhugh creek',
#   'blue mt',
#   'willow creek',
#   'henry gannett, chief geographer. gilbert thompson, geographer in charge. triangulation by the wheeler survey. topography by eugene ricksecker and the wheeler survey.',
#   'eagle creek',
#   'miles',
#   'alturas sheet',
#   'tom creek',
#   'bottle creek',
#   'red rock valley',
#   'ingalls valley',
#   'lassen creek',
#   'hat peak',
#   'rattlesnake butte',
#   'warm',
#   'rattlesnake creek',
#   'pit river',
#   'middle alkalai lake',
#   'henry valley',
#   'alturas hill',
#   'j.w. powell, director',
#   'fandango peak',
#   'hot spring',
#   'california',
#   'antelope plains',
#   'pot hole spring',
#   'jess valley',
#   'modoc',
#   'owl creek',
#   'cedarville',
#   'contour interval 200 feet',
#   'ash creek valley'],
#  'USGS-60-CA-amboy-e1942.jpg': ['mable',
#   'pacific',
#   'cadiz lake',
#   'bonanza king well',
#   '23 mi',
#   'note: officers using this map will mark hereon corrections and additions which come',
#   'atchison',
#   '4600',
#   'old',
#   'sunflower spring',
#   'state route',
#   'salton sea',
#   'martin',
#   'old dad',
#   'weavers well',
#   'to their attention and mail direct to the chief of engineering washington dc',
#   'bristol mountains',
#   'us route',
#   'well',
#   'cooks well',
#   'goffs',
#   'willow springs',
#   'archer',
#   'contour interval 250 feet',
#   '22.5 mi',
#   'calif',
#   'wilhelm camp',
#   '4 lane',
#   'old woman',
#   'fishel',
#   'riverside',
#   'polyconic projection north america datum 1927',
#   'siberia',
#   'unimproved road',
#   'loose-surface graded dry weather road',
#   'arimo',
#   'mountains',
#   'topeka',
#   'clipper',
#   'fenner spring',
#   'piute mountains',
#   '23.5 mi',
#   'bristol lake',
#   'redondo',
#   '3 lane',
#   'control from us geological survey',
#   'iron mountains',
#   'klondike',
#   'fenner',
#   'prepared under the direction of the chief of engineers us army',
#   'quadrangle',
#   '8.5 mi',
#   'e bullion',
#   'bush',
#   'milligan',
#   'scale',
#   'old dad mountains',
#   '66',
#   'granite mountains',
#   'sheep hole mountains',
#   'ship mountains',
#   'road classification',
#   'sandy',
#   'desert center',
#   '3334',
#   'mccoy',
#   'f',
#   'ship',
#   '160',
#   'chubbuck',
#   'siam',
#   'dependable hard-surface heavy-duty road',
#   'twenty thousand yard grid computed from grid system for progressive maps',
#   'blind spring',
#   'and',
#   'providence mountains',
#   'barrel spring',
#   'the last three digits of the grid numbers are omitted',
#   'datum is mean sea level',
#   'beecher spring',
#   'atchison topeka and santa fe',
#   'dale lake',
#   'trojan',
#   'clipper mountains',
#   'n3400-w11500/60',
#   'dry',
#   'pinto mountains',
#   'needles',
#   'provicence mountains',
#   '1873',
#   'santa fe',
#   'cadiz',
#   'more than two lanes indicated by note along road with tick at point of charge',
#   'cotton well',
#   'grid zone',
#   'piute',
#   '12 mi',
#   'honeymoon spring',
#   'van winkle spring',
#   'flynn',
#   'in the us zone f. u. s. c. & g. s. special publication no 59',
#   'chambless',
#   '5300',
#   'bonanza spring',
#   'ludlow',
#   'bagdad',
#   '1415',
#   'county',
#   'bolo station',
#   'spring',
#   'union',
#   'corps of engineers',
#   'california',
#   'essex',
#   'army map service us army washington dc 21494 1942',
#   'woman',
#   'us army',
#   'amboy',
#   'base compiled from us geological surey quadrangles',
#   'san bernardino',
#   'rice',
#   'secondary hard-surface all-weather road',
#   'danby lake',
#   'cove spring',
#   '30',
#   'danby',
#   'war department',
#   'sunflower springs',
#   'revised from state highway maps for california',
#   'glasglow'],
#  'USGS-60-CA-amboy-e1943-rv1943.jpg': ['mable',
#   'pacific',
#   'cadiz lake',
#   'bonanza king well',
#   '23 mi',
#   'note: officers using this map will mark hereon corrections and additions which come',
#   'atchison',
#   '4600',
#   'old',
#   'sunflower spring',
#   'state route',
#   'salton sea',
#   'martin',
#   'old dad',
#   'weavers well',
#   'to their attention and mail direct to the chief of engineering washington dc',
#   'bristol mountains',
#   'us route',
#   'well',
#   'cooks well',
#   'goffs',
#   'willow springs',
#   'archer',
#   'contour interval 250 feet',
#   '22.5 mi',
#   'calif',
#   'wilhelm camp',
#   '4 lane',
#   'old woman',
#   'fishel',
#   'riverside',
#   'polyconic projection north america datum 1927',
#   'siberia',
#   'unimproved road',
#   'loose-surface graded dry weather road',
#   'arimo',
#   'mountains',
#   'topeka',
#   'clipper',
#   'fenner spring',
#   'piute mountains',
#   '23.5 mi',
#   'bristol lake',
#   'redondo',
#   '3 lane',
#   'control from us geological survey',
#   'iron mountains',
#   'klondike',
#   'fenner',
#   'prepared under the direction of the chief of engineers us army',
#   'quadrangle',
#   '8.5 mi',
#   'e bullion',
#   'bush',
#   'milligan',
#   'scale',
#   'old dad mountains',
#   '66',
#   'granite mountains',
#   'sheep hole mountains',
#   'ship mountains',
#   'road classification',
#   'sandy',
#   'desert center',
#   '3334',
#   'mccoy',
#   'f',
#   'ship',
#   '160',
#   'chubbuck',
#   'siam',
#   'dependable hard-surface heavy-duty road',
#   'twenty thousand yard grid computed from grid system for progressive maps',
#   'blind spring',
#   'and',
#   'providence mountains',
#   'barrel spring',
#   'the last three digits of the grid numbers are omitted',
#   'datum is mean sea level',
#   'beecher spring',
#   'atchison topeka and santa fe',
#   'dale lake',
#   'trojan',
#   'clipper mountains',
#   'n3400-w11500/60',
#   'dry',
#   'pinto mountains',
#   'needles',
#   'provicence mountains',
#   '1873',
#   'santa fe',
#   'cadiz',
#   'more than two lanes indicated by note along road with tick at point of charge',
#   'cotton well',
#   'grid zone',
#   'piute',
#   '12 mi',
#   'honeymoon spring',
#   'van winkle spring',
#   'flynn',
#   'in the us zone f. u. s. c. & g. s. special publication no 59',
#   'chambless',
#   '5300',
#   'bonanza spring',
#   'ludlow',
#   'bagdad',
#   '1415',
#   'county',
#   'bolo station',
#   'spring',
#   'union',
#   'corps of engineers',
#   'california',
#   'essex',
#   'army map service us army washington dc 21494 1942',
#   'woman',
#   'us army',
#   'amboy',
#   'base compiled from us geological surey quadrangles',
#   'san bernardino',
#   'rice',
#   'secondary hard-surface all-weather road',
#   'danby lake',
#   'cove spring',
#   '30',
#   'danby',
#   'war department',
#   'sunflower springs',
#   'revised from state highway maps for california',
#   'glasglow'],
#  'USGS-60-CA-modoclavabed-e1886-s1884.jpg': ['nelson creek',
#   'dry lake',
#   'cinder cone',
#   'lookout',
#   'surveyed in 1884-5',
#   'modoc lava bed sheet',
#   'well',
#   'ash',
#   'pecks',
#   'cornell',
#   'widow valley',
#   'kosk creek',
#   'rock creek',
#   'cottonwood creek',
#   'glass m',
#   'grizzly peak',
#   'clear lake',
#   'ferry',
#   'water hole',
#   'bear',
#   'bartless',
#   'lost river',
#   'us geological survey',
#   'geographer in charge',
#   'bear creek',
#   'stone coat valley',
#   'kerr',
#   'double head',
#   'pittville',
#   'lava bed',
#   'big valley',
#   'creek',
#   'butter creek',
#   'snake island',
#   'ice cave',
#   'henry gannett',
#   'antelope creek',
#   'dome m',
#   'river',
#   'pit',
#   'siskiyou modoc',
#   'scale',
#   'jw powell director',
#   'ah thompson',
#   'shasta lassen',
#   'topography by mb kerr and eugene ricksecker',
#   'modoc lava bed',
#   'modoc rifle pit',
#   'south fork',
#   'burgettville',
#   'caton valley',
#   'timber m',
#   'triangulation by mark b. kerr',
#   'ridges',
#   'bieber',
#   'kosk',
#   'fort',
#   'ricksecker',
#   'egg flat',
#   'willow creek',
#   'bloody paint',
#   'turret',
#   'doris',
#   'crater',
#   'trout creek',
#   'little klamath lake',
#   'geographer',
#   'spring',
#   'hot spring',
#   'california',
#   'black fox m',
#   'm hoffmann',
#   'springs',
#   'medicine lake',
#   'white horse valley',
#   'chief geographer',
#   'clark creek',
#   'fall',
#   'fairchild',
#   'lava',
#   'm. cloud',
#   'contour interval 200 feet',
#   'happy camp',
#   'rhett lake'],
#  'USGS-60-CA-saltonsea-e1943-ap1940-rv1942.jpg': ['chuckwalla well',
#   'shavers summit',
#   'blythe 23 mi.',
#   'palen dry lake',
#   'state route',
#   'summit mt',
#   'salton sea',
#   'cottonwood spring',
#   'colima tunnel',
#   '35 miles',
#   'coachella 28 mi.',
#   'ford dry lake',
#   'hopkins well',
#   'joshua',
#   'combat range area',
#   'southern pacific',
#   'cottonwood mountains',
#   'water point',
#   'dependable hard surface, heavy duty road.',
#   "approximate mean declination 1943 annual magenatic change 1' increase",
#   'bombay beach',
#   'mesquite',
#   'niland',
#   'bliss',
#   'mammoth',
#   'paint pot spring',
#   'desert center airport',
#   'durmid',
#   'new river',
#   'bertram',
#   'aztec well',
#   'weist',
#   'cottonwood',
#   'obsidian buttes',
#   'riverside imperial',
#   'yuma',
#   'aztec well road',
#   'pope',
#   'chuckwalla valley',
#   'tortuga',
#   'combat range',
#   'eagle mts',
#   'service sta',
#   'mountains',
#   'shamrock',
#   'dos palmas',
#   'carrizo creek',
#   'joshua tree',
#   'truckhaven',
#   'national monument',
#   'pinto basin',
#   '60 kilometers',
#   'salvation pass',
#   'el centro',
#   'possible landing field',
#   'contour interval 500 feet',
#   'amos',
#   'road classifications',
#   'little san bernardino mountains',
#   'arroyo seco',
#   'twin mounds',
#   'granite mts',
#   'rockwood',
#   'salton sea, calif.',
#   'shavers well',
#   'calipatria',
#   'palen mountains',
#   'desert center',
#   'east side highline canal',
#   'estelle',
#   'east mesa',
#   'kane springs',
#   'black butte',
#   'pinkham well',
#   'wister',
#   'cadiz valley',
#   'orocopia mts',
#   'water surface 250 feet below sea level',
#   'u.s. route',
#   'julian 42 mi.',
#   'brawley 5 mi.',
#   'mortmar',
#   'imperial county',
#   'u s n air base',
#   'harper well',
#   'mecca to dale road',
#   'munyon',
#   'san felipe creek',
#   'mesquite drill hole',
#   'frink',
#   'datum is mean sea level',
#   'pumice buttes',
#   'salton beach',
#   'road classificationsloose surface graded, dry weather road.',
#   'restricted',
#   'yuma 32 mi.',
#   'sand hills',
#   'beals well',
#   'mundo',
#   'eldorado mine',
#   'needles',
#   'palen pass',
#   'cottonwood pass',
#   'coachella canal',
#   'hidden springs',
#   'verdant',
#   'bernice',
#   'mecca 3.5 mi.',
#   'soft sand',
#   'camp young',
#   'advance edition subject to correctionll',
#   'mullet island',
#   'salt spring',
#   'riverside county',
#   'arroyo grande',
#   'mammoth wash',
#   'culture revisions august,1942 based on recomnaissance by 67th engr. co. (top.)',
#   'chuckwalla mts',
#   'california salton sea quadrangle grid zone "f"',
#   'lost palms',
#   'chocolate mountains',
#   'little chuckwalla mountains',
#   'eagle mountain pumping plant',
#   'dam highway',
#   'iron chief mine',
#   'trifolium canal',
#   'secondary, hard surface, all weather road.',
#   'war department corps of engineers, u.s. army',
#   'alamo river',
#   'possible camouflage area',
#   'priest mine',
#   'sea level',
#   'scott mine',
#   'colton gun club',
#   'blythe',
#   'eagle mt tunnel',
#   'salton',
#   'cottonwood tunnel',
#   'coxcomb mountains',
#   'u s m base',
#   'salton creek',
#   'amboy',
#   'sandia branch',
#   'date palm beach',
#   'hayfield reservoir',
#   'mccain spring',
#   'indio 14 mi.',
#   'fonda',
#   'red clood mine',
#   'unimproved road.',
#   'granite mine',
#   'acolita',
#   'holtville 17 mi.',
#   'flowing well',
#   'turn',
#   'westmorland',
#   'sea view',
#   'soda spring',
#   'skylark garage']}

# %%
import json

with open('map_phrase_USGS(GT).json', 'w') as f:
    json.dump(phrase_dic, f)
